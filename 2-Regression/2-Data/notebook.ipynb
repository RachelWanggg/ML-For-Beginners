# %%
import pandas as pd
import  matplotlib.pyplot as plt

# %%
pumpkins = pd.read_csv('../data/US-pumpkins.csv')
pumpkins = pumpkins[pumpkins['Package'].str.contains('bushel', case=True, regex=True)]
pumpkins.head()
# Out:
#     City Name Type               Package   Variety Sub Variety  Grade  \
# 70  BALTIMORE  NaN  1 1/9 bushel cartons  PIE TYPE         NaN    NaN
# 71  BALTIMORE  NaN  1 1/9 bushel cartons  PIE TYPE         NaN    NaN
# 72  BALTIMORE  NaN  1 1/9 bushel cartons  PIE TYPE         NaN    NaN
# 73  BALTIMORE  NaN  1 1/9 bushel cartons  PIE TYPE         NaN    NaN
# 74  BALTIMORE  NaN  1 1/9 bushel cartons  PIE TYPE         NaN    NaN
#
#        Date  Low Price  High Price  Mostly Low  ...  Unit of Sale Quality  \
# 70  9/24/16       15.0        15.0        15.0  ...           NaN     NaN
# 71  9/24/16       18.0        18.0        18.0  ...           NaN     NaN
# 72  10/1/16       18.0        18.0        18.0  ...           NaN     NaN
# 73  10/1/16       17.0        17.0        17.0  ...           NaN     NaN
# 74  10/8/16       15.0        15.0        15.0  ...           NaN     NaN
#
#    Condition Appearance Storage  Crop Repack  Trans Mode  Unnamed: 24  \
# ...

# %%
pumpkins.isnull().sum()
# Out:
# City Name            0
# Type               406
# Package              0
# Variety              0
# Sub Variety        167
# Grade              415
# Date                 0
# Low Price            0
# High Price           0
# Mostly Low          24
# Mostly High         24
# Origin               0
# Origin District    396
# Item Size          114
# Color              145
# Environment        415
# Unit of Sale       404
# Quality            415
# Condition          415
# Appearance         415
# Storage            415
# Crop               415
# Repack               0
# Trans Mode         415
# Unnamed: 24        415
# Unnamed: 25        391
# dtype: int64

# %%
columns_to_select = ['City Name', 'Low Price', 'High Price', 'Package']
pumpkins = pumpkins.loc[:, columns_to_select]

# %%
price = (pumpkins['Low Price'] + pumpkins['High Price']) / 2

pumpkins = pd.DataFrame({'Origin': pumpkins['City Name'], 'Package': pumpkins['Package'], 'Low Price': pumpkins['Low Price'],'High Price': pumpkins['High Price'], 'Price': price})


pumpkins.loc[pumpkins['Package'].str.contains('1 1/9'), 'Price'] = price/(1 + 1/9)

pumpkins.loc[pumpkins['Package'].str.contains('1/2'), 'Price'] = price/(1/2)

print(pumpkins)
# Out:
#          Origin               Package  Low Price  High Price  Price
# 70    BALTIMORE  1 1/9 bushel cartons      15.00        15.0  13.50
# 71    BALTIMORE  1 1/9 bushel cartons      18.00        18.0  16.20
# 72    BALTIMORE  1 1/9 bushel cartons      18.00        18.0  16.20
# 73    BALTIMORE  1 1/9 bushel cartons      17.00        17.0  15.30
# 74    BALTIMORE  1 1/9 bushel cartons      15.00        15.0  13.50
# ...         ...                   ...        ...         ...    ...
# 1738  ST. LOUIS    1/2 bushel cartons      15.00        15.0  30.00
# 1739  ST. LOUIS    1/2 bushel cartons      13.75        15.0  28.75
# 1740  ST. LOUIS    1/2 bushel cartons      10.75        15.0  25.75
# 1741  ST. LOUIS    1/2 bushel cartons      12.00        12.0  24.00
# 1742  ST. LOUIS    1/2 bushel cartons      12.00        12.0  24.00
#
# [415 rows x 5 columns]

# %%
pumpkins.groupby(['Origin'])['Price'].mean().plot(kind='bar')
plt.ylabel("Pumpkin Price")
# Out:
# Text(0, 0.5, 'Pumpkin Price')
